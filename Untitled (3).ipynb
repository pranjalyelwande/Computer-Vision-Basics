# %%
Que.python program to check if a number is Even or Odd.
program:-
    
p=int(input("Enter no:"))
if p%2==0:
    print("Number is Even")
else:
    print("Number is Odd")
    
output:
# Out:
# Enter no:56
# Number is Even
